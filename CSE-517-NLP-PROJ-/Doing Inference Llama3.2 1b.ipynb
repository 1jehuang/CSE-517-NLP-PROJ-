# %%
# adws# prompt: load drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Define the directory where the model is saved
load_directory = "/content/drive/Shareddrives/517 nlp project/Models/Llama-3.2-1B-Instruct"

# Load the model and tokenizer from the specified directory
tokenizer = AutoTokenizer.from_pretrained(load_directory)
model = AutoModelForCausalLM.from_pretrained(load_directory)

print("Model and tokenizer successfully loaded from Google Drive!")
# Out:
# Model and tokenizer successfully loaded from Google Drive!

# %%
import time
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the model and tokenizer
load_directory = "/content/drive/Shareddrives/517 nlp project/Models/Llama-3.2-1B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(load_directory)
model = AutoModelForCausalLM.from_pretrained(load_directory).to("cuda")

# Ensure the tokenizer has a pad_token
if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({'pad_token': tokenizer.eos_token})
    model.resize_token_embeddings(len(tokenizer))  # Resize model's embedding matrix if a new token is added

# Prompt the model to generate the longest possible response
prompt = (
    "debate relgiion and atheism to completition"
)

# Tokenize the input
inputs = tokenizer(prompt, return_tensors="pt", padding=True).to("cuda")

# Measure inference time
start_time = time.time()

# Generate output with maximum length
output = model.generate(
    inputs.input_ids,
    max_length=2048,  # Maximum length for generation
    temperature=0.8,  # Controls randomness; lower is more deterministic
    top_p=0.9,        # Controls diversity
    repetition_penalty=1.1,  # Penalizes repetitive output
    do_sample=True,   # Enables sampling
    use_cache=True,   # Optimizes performance by caching computations
    pad_token_id=tokenizer.pad_token_id  # Explicitly set pad_token_id
)

# Measure the time taken
end_time = time.time()

# Decode the output
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

# Calculate metrics
elapsed_time = end_time - start_time
tokens_generated = len(generated_text.split())  # Approximate number of tokens
tokens_per_second = tokens_generated / elapsed_time

# Print the response
print("--- Generated Response ---")
print(generated_text)

# Print performance statistics
print("\n--- Performance Statistics ---")
print(f"Elapsed Time: {elapsed_time:.2f} seconds")
print(f"Tokens Generated: {tokens_generated}")
print(f"Tokens per Second: {tokens_per_second:.2f}")
print(f"Prompt Length (Tokens): {inputs.input_ids.shape[-1]}")
print(f"Generated Length (Tokens): {tokens_generated}")
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# --- Generated Response ---
# debate relgiion and atheism to completition
# A long-time debate between theists and atheists has been ongoing for centuries. Debates over religion, faith, and spirituality have sparked passionate discussions across cultures, societies, and generations. While some view these debates as opportunities to explore different perspectives and challenge each other's beliefs, others see them as divisive and hurtful. The following is a comprehensive exploration of both sides of this contentious issue.
#
# **Argument in favor of Religions:**
#
# Religious teachings often provide a sense of community and belonging, which can be especially important during times of social isolation or economic hardship. Many people find comfort and support within their faith communities, where they feel understood, accepted, and empowered by the shared values and practices of their group. Religious institutions also play a vital role in providing education, healthcare, and social services, making significant contributions to the well-being of individuals and society as a whole.
#
# Furthermore, religious texts often contain valuable moral lessons, wisdom stories, and spiritual guidance that can shape individual behavior and foster personal growth. For many people, faith provides a framework for navigating life's challenges and finding meaning and purpose in their existence.
#
# Additionally, religions offer unique cultural identities and traditions, allowing adherents to connect with their heritage and express themselves authentically. Whether it's through art, music, literature, or performance, religious expressions enrich our understanding of the human experience and inspire empathy, compassion, and kindness towards others.
#
# **Argument against Religions:**
#
# Critics argue that religions often rely on dogma, scripture, and authority figures to justify their teachings, leading to a lack of critical thinking, intellectual curiosity, and open-mindedness. This can result in the suppression of dissenting views, intolerance of opposing ideas, and a fear-mongering atmosphere that perpetuates division and polarization.
#
# Moreover, the claims made by religions are frequently based on flawed interpretations, mythological narratives, and biases, which can lead to misinformation, misconceptions, and misunderstandings about various aspects of reality, including science, history, and ethics. Some argue that the influence of religious leaders and institutions can create a hierarchical structure, perpetuating power imbalances and reinforcing social inequalities.
#
# Others point out that many religious texts contain violence, oppression, and discrimination, particularly when applied to marginalized groups such as women, minorities, and LGBTQ+ individuals. These contradictions undermine the idea that religions can provide objective truth or moral guidance.
#
# **Addressing Criticisms and Finding Common Ground:**
#
# While disagreements regarding the nature and limitations of religion remain, there are areas where mutual respect and openness can facilitate constructive dialogue:
#
# 1.  **Critical inquiry**: Encourage critical examination of religious texts, sources, and practices to identify potential flaws and biases.
# 2.  **Respectful listening**: Create spaces for respectful discussion and listening, avoiding the use of dogmatic language and promoting an environment of empathy and understanding.
# 3.  **Seeking common ground**: Explore the interests, concerns, and experiences of those who hold differing views, aiming to understand the underlying motivations and values driving their perspectives.
# 4.  **Embracing diverse perspectives**: Celebrate the diversity of human experiences and promote a culture of inclusivity, where everyone feels valued and respected.
# 5.  **Fostering interfaith dialogue**: Organize workshops, lectures, and cultural events that bring together representatives from different faiths to share knowledge, exchange ideas, and build bridges of understanding.
#
# By adopting a spirit of cooperation and open-mindedness, we can work towards creating a more inclusive and compassionate society, one where diverse viewpoints are valued and respected, and individuals can grow and thrive in harmony with others.
#
# --- Performance Statistics ---
# Elapsed Time: 20.53 seconds
# Tokens Generated: 565
# Tokens per Second: 27.52
# Prompt Length (Tokens): 12
# Generated Length (Tokens): 565

# %%
import re

def extract_equation(text):
    """Extracts the equation from the generated text using regular expressions."""
    match = re.search(r"[-+*/()]?\d+\s*[-+*/()]\s*\d+", text)  # Find simple arithmetic operations
    if match:
        return match.group(0)  # Return the matched equation
    else:
        return ""  # Return empty string if no equation is found

# %%
import pandas as pd
from sklearn.metrics import accuracy_score

# %%
import pandas as pd

# Load dataset
dataset_path = "/content/drive/Shareddrives/517 nlp project/data/SVAMP/data/mawps-asdiv-a_svamp_without_questions/dev.csv"
df = pd.read_csv(dataset_path)

# Define formatting function - now without showing the answer
def format_question(row):
    # Get the numbers from the Numbers column
    numbers = row['Numbers'].split()

    # Replace number0, number1, etc with actual values
    body = row['Body']
    question = row['Ques']

    for i, num in enumerate(numbers):
        body = body.replace(f'number{i}', num)
        question = question.replace(f'number{i}', num)

    return f"Problem: {body}\nQuestion: {question}"

# Create formatted question column with actual numbers
df['formatted_question'] = df.apply(format_question, axis=1)

# Display first 3 examples with clear formatting
print("Sample formatted questions:\n")
for idx, row in df.head(3).iterrows():
    print(f"Example {idx + 1}:")
    print(f"{row['formatted_question']}")
    print(f"Answer (not shown to model): {row['Answer']}")
    print("---\n")
# Out:
# Sample formatted questions:
#
# Example 1:
# Problem: julia played tag with 18 kids on monday . she played tag with 10 kids on tuesday .
# Question: how many more kids did she play with on monday than on tuesday ?
# Answer (not shown to model): 8.0
# ---
#
# Example 2:
# Problem: julia played tag with 11 kids on monday . she played tag with 12 kids on tuesday .
# Question: how many more kids did she play with on tuesday than on monday ?
# Answer (not shown to model): 1.0
# ---
#
# Example 3:
# Problem: julia played tag with 5 kids on monday . she played tag with some more kids on tuesday . if she played with a total of 15 kids
# Question: how many kids did she play with on tuesday ?
# Answer (not shown to model): 10.0
# ---

# %%
def generate_math_prompt(question):
    prompt = f"""Solve this math word problem step by step:

{question}

Let's solve this step by step:
1) First, understand what is being asked
2) Then, identify the important information
3) Solve step by step
4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]

Show your work:"""
    return prompt

def extract_answer(response):
    """Extract the numerical answer from between [ANSWER] tags"""
    try:
        # Look for answer between tags
        import re
        pattern = r'\[ANSWER\](\d+\.?\d*)\[\/ANSWER\]'
        match = re.search(pattern, response)
        if match:
            return float(match.group(1))

        # Fallback: look for last number after "answer is" or similar phrases
        patterns = [
            r'answer is[^\d]*(\d+\.?\d*)',
            r'answer:[^\d]*(\d+\.?\d*)',
            r'equals[^\d]*(\d+\.?\d*)',
            r'=\s*(\d+\.?\d*)'
        ]

        for pattern in patterns:
            match = re.search(pattern, response.lower())
            if match:
                return float(match.group(1))

        # Final fallback: last number in response
        numbers = re.findall(r'\d+\.?\d*', response)
        if numbers:
            return float(numbers[-1])

        return None
    except:
        return None

# %%
# Run inference on test set
predictions = []
actual = []
start_time = time.time()

# ANSI color codes
BLUE = '\033[94m'
GREEN = '\033[92m'
RED = '\033[91m'
YELLOW = '\033[93m'
CYAN = '\033[96m'
PURPLE = '\033[95m'  # New color for model response
ENDC = '\033[0m'

# Take first 10 examples for testing
total_questions = len(df.head(10))

for idx, row in df.head(10).iterrows():
    question = row['formatted_question']
    prompt = generate_math_prompt(question)

    # Generate response
    inputs = tokenizer(prompt, return_tensors="pt", padding=True).to("cuda")
    output = model.generate(
        inputs.input_ids,
        max_length=512,
        temperature=0.1,  # Lower temperature for more focused answers
        do_sample=True,
        num_beams=3,      # Add beam search for better coherence
        top_p=0.9,        # Nucleus sampling
        repetition_penalty=1.2  # Increased penalty for repetition
    )
    response = tokenizer.decode(output[0], skip_special_tokens=True)

    # Extract numerical answer
    predicted = extract_answer(response)
    if predicted is not None:
        predictions.append(predicted)
        actual.append(float(row['Answer']))

        is_correct = abs(predicted - float(row['Answer'])) < 0.01
        correct_color = GREEN if is_correct else RED

        # Print progress and time estimation
        questions_done = len(predictions)
        questions_left = total_questions - questions_done
        elapsed_time = time.time() - start_time
        avg_time_per_question = elapsed_time / questions_done if questions_done > 0 else 0
        estimated_time_left = questions_left * avg_time_per_question

        print(f"\n{CYAN}Progress: {questions_done}/{total_questions} questions{ENDC}")
        print(f"{CYAN}Average time per question: {avg_time_per_question:.1f} seconds{ENDC}")
        print(f"{CYAN}Estimated time remaining: {estimated_time_left/60:.1f} minutes{ENDC}\n")

        # Print results
        print(f"\n{YELLOW}Question {idx}:{ENDC}")
        print(f"{BLUE}Prompt: {question}{ENDC}")
        print(f"{YELLOW}Model response:{ENDC}")
        print(f"{PURPLE}{response}{ENDC}")  # Color the entire response
        print(f"{correct_color}Correct: {is_correct}{ENDC}")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 1/10 questions
# Average time per question: 6.4 seconds
# Estimated time remaining: 1.0 minutes
#
#
# Question 0:
# Prompt: Problem: julia played tag with 18 kids on monday . she played tag with 10 kids on tuesday .
# Question: how many more kids did she play with on monday than on tuesday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 18 kids on monday. she played tag with 10 kids on tuesday.
# Question: how many more kids did she play with on monday than on tuesday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work: Step 1-4
#
# Step 1: Understand what is being asked
# The problem is asking how many more kids Julia played with on Monday than on Tuesday.
#
# Step 2: Identify the important information
# The number of kids Julia played with on Monday is 18, and the number of kids she played with on Tuesday is 10.
#
# Step 3: Solve step by step
# To find out how many more kids Julia played with on Monday than on Tuesday, we need to subtract the number of kids she played with on Tuesday from the number of kids she played with on Monday.
# 18 (kids on Monday) - 10 (kids on Tuesday) = 8
#
# Step 4: State the answer in the format: [ANSWER]<number>[/ANSWER]
#
# ANSWER<8>[/ANSWER]
# Correct: True
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 2/10 questions
# Average time per question: 6.7 seconds
# Estimated time remaining: 0.9 minutes
#
#
# Question 1:
# Prompt: Problem: julia played tag with 11 kids on monday . she played tag with 12 kids on tuesday .
# Question: how many more kids did she play with on tuesday than on monday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 11 kids on monday. she played tag with 12 kids on tuesday.
# Question: how many more kids did she play with on tuesday than on monday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work: Step 1-4
#
# Step 1: Understand what is being asked
# Julia played tag with 11 kids on Monday and 12 kids on Tuesday. We need to find out how many more kids she played with on Tuesday than on Monday.
#
# Step 2: Identify the important information
# The number of kids Julia played tag with on Monday is 11.
# The number of kids Julia played tag with on Tuesday is 12.
#
# Step 3: Solve step by step
# To find out how many more kids she played with on Tuesday than on Monday, we need to subtract the number of kids she played with on Monday from the number of kids she played with on Tuesday.
# 12 (kids on Tuesday) - 11 (kids on Monday) = 1
#
# Step 4: State the answer in the format: [ANSWER]<number>[/ANSWER]
#
# ANSWER1[/ANSWER]
# Correct: True
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 3/10 questions
# Average time per question: 6.0 seconds
# Estimated time remaining: 0.7 minutes
#
#
# Question 2:
# Prompt: Problem: julia played tag with 5 kids on monday . she played tag with some more kids on tuesday . if she played with a total of 15 kids
# Question: how many kids did she play with on tuesday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 5 kids on monday. she played tag with some more kids on tuesday. if she played with a total of 15 kids
# Question: how many kids did she play with on tuesday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work:
#
# Step 1: Understand what is being asked
# Julia played tag with a total of 15 kids.
#
# Step 2: Identify the important information
# Julia played tag with 5 kids on Monday.
#
# Step 3: Solve step by step
# To find out how many kids Julia played with on Tuesday, we need to subtract the number of kids she played with on Monday from the total number of kids she played with.
#
# 15 (total kids) - 5 (kids on Monday) = 10
#
# So, Julia played with 10 kids on Tuesday.
#
# ANSWER 10[/ANSWER]
# Correct: True
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 4/10 questions
# Average time per question: 5.7 seconds
# Estimated time remaining: 0.6 minutes
#
#
# Question 3:
# Prompt: Problem: julia played tag with some kids on monday . she played tag with 14 kids on tuesday . if she played with a total of 16 kids
# Question: how many kids did she play with on monday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with some kids on monday. she played tag with 14 kids on tuesday. if she played with a total of 16 kids
# Question: how many kids did she play with on monday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work:
#
# Step 1: Understand what is being asked
# The problem is asking how many kids Julia played with on Monday.
#
# Step 2: Identify the important information
# We know that Julia played tag with 14 kids on Tuesday and a total of 16 kids.
#
# Step 3: Solve step by step
# To find out how many kids Julia played with on Monday, we need to subtract the number of kids she played with on Tuesday from the total number of kids.
#
# 16 (total kids) - 14 (kids on Tuesday) = 2
#
# So, Julia played with 2 kids on Monday.
#
# ANSWER=2[/ANSWER]
# Correct: True
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 5/10 questions
# Average time per question: 5.9 seconds
# Estimated time remaining: 0.5 minutes
#
#
# Question 4:
# Prompt: Problem: julia played tag with 16 kids on monday . if she played tag with 12 more kids on monday than on tuesday
# Question: how many kids did she play with on tuesday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 16 kids on monday. if she played tag with 12 more kids on monday than on tuesday
# Question: how many kids did she play with on tuesday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work:
#
# Step 1: Understand what is being asked
# Julia played tag with 16 kids on Monday.
#
# Step 2: Identify the important information
# Julia played tag with 12 more kids on Monday than on Tuesday.
#
# Step 3: Solve step by step
# Let x be the number of kids Julia played with on Tuesday.
# Then, the number of kids she played with on Monday is x + 12.
# Since Julia played with 16 kids on Monday, we can set up the equation:
# x + 12 = 16
#
# Step 4: Solve for x
# Subtract 12 from both sides of the equation:
# x = 16 - 12
# x = 4
#
# Step 5: State the answer in the format: [ANSWER]<number>[/ANSWER]
# ANSWER<4>[/ANSWER]
# Correct: False
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 6/10 questions
# Average time per question: 5.9 seconds
# Estimated time remaining: 0.4 minutes
#
#
# Question 5:
# Prompt: Problem: julia played tag with 14 kids on tuesday . if she played tag with 8 more kids on monday than on tuesday
# Question: how many kids did she play with on monday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 14 kids on tuesday. if she played tag with 8 more kids on monday than on tuesday
# Question: how many kids did she play with on monday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work:
#
# Step 1: Understand what is being asked
# Julia played tag with 14 kids on Tuesday. She played tag with 8 more kids on Monday than on Tuesday.
#
# Step 2: Identify the important information
# The number of kids Julia played tag with on Monday is 8 more than the number of kids she played with on Tuesday.
#
# Step 3: Solve step by step
# Let x be the number of kids Julia played with on Monday.
# x = Tuesday's kids + 8
# x = 14 + 8
# x = 22
#
# So, Julia played tag with 22 kids on Monday.
#
# Step 4: State the answer in the format: [ANSWER]<number>[/ANSWER]
#
# ANSWER<22>[/ANSWER]
# Correct: False
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 7/10 questions
# Average time per question: 6.0 seconds
# Estimated time remaining: 0.3 minutes
#
#
# Question 6:
# Prompt: Problem: julia played tag with 17 kids on monday 15 kids on tuesday and 2 kids on wednesday .
# Question: how many kids did she play with altogether ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 17 kids on monday 15 kids on tuesday and 2 kids on wednesday.
# Question: how many kids did she play with altogether?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work:
#
# Step 1: Understand what is being asked
# Julia played tag with 17 kids on Monday, 15 kids on Tuesday, and 2 kids on Wednesday.
#
# Step 2: Identify the important information
# We need to find the total number of kids Julia played with altogether.
#
# Step 3: Solve step by step
# To find the total number of kids Julia played with, we need to add the number of kids she played with on Monday, Tuesday, and Wednesday.
#
# Total number of kids = Number of kids on Monday + Number of kids on Tuesday + Number of kids on Wednesday
# Total number of kids = 17 + 15 + 2
#
# Step 4: Calculate the total number of kids
# Total number of kids = 17 + 15 + 2
# Total number of kids = 34
#
# ANSWER [34][/ANSWER]
# Correct: False
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 8/10 questions
# Average time per question: 6.1 seconds
# Estimated time remaining: 0.2 minutes
#
#
# Question 7:
# Prompt: Problem: julia played tag with 15 kids on monday 18 kids on tuesday and 97 kids on wednesday .
# Question: how many kids did she play with on monday and tuesday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 15 kids on monday 18 kids on tuesday and 97 kids on wednesday.
# Question: how many kids did she play with on monday and tuesday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work:
#
# Step 1: Understand what is being asked
# Julia played tag with 15 kids on Monday, 18 kids on Tuesday, and 97 kids on Wednesday.
#
# Step 2: Identify the important information
# We need to find the total number of kids Julia played with on Monday and Tuesday.
#
# Step 3: Solve step by step
# To find the total number of kids Julia played with on Monday and Tuesday, we need to add the number of kids she played with on Monday and Tuesday.
#
# Number of kids Julia played with on Monday = 15
# Number of kids Julia played with on Tuesday = 18
#
# Total number of kids Julia played with on Monday and Tuesday = 15 + 18 = 33
#
# Step 4: State the answer in the format: [ANSWER]<number>[/ANSWER]
#
# ANSWER<33>[/ANSWER]
# Correct: False
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Progress: 9/10 questions
# Average time per question: 6.0 seconds
# Estimated time remaining: 0.1 minutes
#
#
# Question 8:
# Prompt: Problem: julia played tag with 5 kids on monday 9 kids on tuesday and 15 kids on wednesday .
# Question: how many kids did she play with on monday and wednesday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 5 kids on monday 9 kids on tuesday and 15 kids on wednesday.
# Question: how many kids did she play with on monday and wednesday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work:
#
# Step 1: Identify the important information
# Julia played tag with 5 kids on Monday, 9 kids on Tuesday, and 15 kids on Wednesday.
#
# Step 2: Solve step by step
# To find the total number of kids Julia played with on Monday and Wednesday, we need to add the number of kids she played with on each of those days.
#
# Monday: 5 kids
# Tuesday: 9 kids
# Wednesday: 15 kids
#
# Total kids on Monday and Wednesday: 5 + 9 + 15 = 29
#
# Therefore, Julia played with 29 kids on Monday and Wednesday.
#
# ANSWER 29[/ANSWER]
# Correct: False
#
# Progress: 10/10 questions
# Average time per question: 6.0 seconds
# Estimated time remaining: 0.0 minutes
#
#
# Question 9:
# Prompt: Problem: julia played tag with 2 kids on monday 14 kids on tuesday and 16 kids on wednesday .
# Question: how many kids did she play with on tuesday and wednesday ?
# Model response:
# Solve this math word problem step by step:
#
# Problem: julia played tag with 2 kids on monday 14 kids on tuesday and 16 kids on wednesday.
# Question: how many kids did she play with on tuesday and wednesday?
#
# Let's solve this step by step:
# 1) First, understand what is being asked
# 2) Then, identify the important information
# 3) Solve step by step
# 4) Finally, state the answer in the format: [ANSWER]<number>[/ANSWER]
#
# Show your work:
#
# Step 1: Understand what is being asked
# Julia played tag with 2 kids on Monday, 14 kids on Tuesday, and 16 kids on Wednesday.
#
# Step 2: Identify the important information
# We need to find the total number of kids Julia played with on Tuesday and Wednesday.
#
# Step 3: Solve step by step
# To find the total number of kids Julia played with on Tuesday and Wednesday, we need to add the number of kids she played with on each day.
# Tuesday: 14 kids
# Wednesday: 16 kids
# Total: 14 + 16 = 30 kids
#
# Step 4: State the answer in the format: [ANSWER]<number>[/ANSWER]
#
# ANSWER<30>[/ANSWER]
# Correct: True

# %%
# Calculate accuracy
import numpy as np
predictions = np.array(predictions)
actual = np.array(actual)
correct = 0
errors = np.abs(predictions - actual)
print(f"Mean absolute error: {errors.mean():.2f}")
print(f"Median absolute error: {np.median(errors):.2f}")
# Out:
# Mean absolute error: 6.40
# Median absolute error: 4.00

# %% [markdown]
# NOTE: FOR THE SVAMP DATASET, there are multiple folders. there are three datasets, easy math, med math, and harder math. for two of the datasets, they have a question version and a no question version. i find they are identicle. they also have a combined (all three) dataset (there is one labeled questions and one labeled no questions). just use one of the combined datasets
