# %%
# Download hotpotqa
# !git clone https://github.com/hotpotqa/hotpot.git
# Out:
# Cloning into 'hotpot'...
# remote: Enumerating objects: 42, done.
# remote: Total 42 (delta 0), reused 0 (delta 0), pack-reused 42 (from 1)
# Receiving objects: 100% (42/42), 36.33 KiB | 664.00 KiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !hotpot/download.sh
# Out:
# --2025-02-02 22:42:24--  http://curtis.ml.cmu.edu/datasets/hotpot/hotpot_dev_distractor_v1.json
# Resolving curtis.ml.cmu.edu (curtis.ml.cmu.edu)... 128.2.204.193
# Connecting to curtis.ml.cmu.edu (curtis.ml.cmu.edu)|128.2.204.193|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46320117 (44M) [application/json]
# Saving to: ‘hotpot_dev_distractor_v1.json’
#
# hotpot_dev_distract 100%[===================>]  44.17M  32.0MB/s    in 1.4s
#
# 2025-02-02 22:42:25 (32.0 MB/s) - ‘hotpot_dev_distractor_v1.json’ saved [46320117/46320117]
#
# --2025-02-02 22:42:25--  http://curtis.ml.cmu.edu/datasets/hotpot/hotpot_dev_fullwiki_v1.json
# Resolving curtis.ml.cmu.edu (curtis.ml.cmu.edu)... 128.2.204.193
# Connecting to curtis.ml.cmu.edu (curtis.ml.cmu.edu)|128.2.204.193|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47454698 (45M) [application/json]
# Saving to: ‘hotpot_dev_fullwiki_v1.json’
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp *.json /content/drive/Shareddrives/517\ nlp\ project/data/HotpotQA/
# Out:
# Mounted at /content/drive

# %%
# !wget http://curtis.ml.cmu.edu/datasets/hotpot/hotpot_test_fullwiki_v1.json
# !mv hotpot_test_fullwiki_v1.json /content/drive/Shareddrives/517\ nlp\ project/data/HotpotQA/
# Out:
# --2025-02-03 01:46:06--  http://curtis.ml.cmu.edu/datasets/hotpot/hotpot_test_fullwiki_v1.json
# Resolving curtis.ml.cmu.edu (curtis.ml.cmu.edu)... 128.2.204.193
# Connecting to curtis.ml.cmu.edu (curtis.ml.cmu.edu)|128.2.204.193|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46213747 (44M) [application/json]
# Saving to: ‘hotpot_test_fullwiki_v1.json’
#
# hotpot_test_fullwik 100%[===================>]  44.07M  74.1MB/s    in 0.6s
#
# 2025-02-03 01:46:07 (74.1 MB/s) - ‘hotpot_test_fullwiki_v1.json’ saved [46213747/46213747]
