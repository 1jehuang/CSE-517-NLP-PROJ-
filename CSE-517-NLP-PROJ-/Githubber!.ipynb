# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/517 nlp project
# Out:
# /content/drive/Shareddrives/517 nlp project

# %%
# !git clone https://github.com/1jehuang/CSE-517-NLP-PROJ-.git
# Out:
# Cloning into 'CSE-517-NLP-PROJ-'...
# ...

# %%
# # Move Models folder into the GitHub repo
# !mv "/content/drive/Shareddrives/517 nlp project/Models" "/content/drive/Shareddrives/517 nlp project/CSE-517-NLP-PROJ-/Models"

# # Move data folder into the GitHub repo
# !mv "/content/drive/Shareddrives/517 nlp project/data" "/content/drive/Shareddrives/517 nlp project/CSE-517-NLP-PROJ-/data"

# # Move Jupyter notebooks into the GitHub repo
# !mv "/content/drive/Shareddrives/517 nlp project/*.ipynb" "/content/drive/Shareddrives/517 nlp project/CSE-517-NLP-PROJ-/"
# Out:
# mv: cannot stat '/content/drive/Shareddrives/517 nlp project/*.ipynb': No such file or directory

# %%
# Move all .ipynb files from "517 nlp project" into the GitHub repo folder
# !mv "/content/drive/Shareddrives/517 nlp project/"*.ipynb "/content/drive/Shareddrives/517 nlp project/CSE-517-NLP-PROJ-/"

# %%
# %cd "/content/drive/Shareddrives/517 nlp project/CSE-517-NLP-PROJ-"
# !git add .
# !git commit -m "Added Jupyter notebooks"
# !git push origin main
# Out:
# /content/drive/Shareddrives/517 nlp project/CSE-517-NLP-PROJ-
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.name "1jehuang"
# !git config --global user.email "jeremyhuang55555@gmail.com"
