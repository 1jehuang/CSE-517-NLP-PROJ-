# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Step 2: Clone the SVAMP repository
# !git clone https://github.com/arkilpatel/SVAMP.git

# Step 3: Copy the dataset to the specified location
# !cp -r SVAMP /content/drive/Shareddrives/517\ nlp\ project/
# Out:
# Cloning into 'SVAMP'...
# remote: Enumerating objects: 397, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 397 (delta 37), reused 27 (delta 27), pack-reused 335 (from 1)
# Receiving objects: 100% (397/397), 1.63 MiB | 3.15 MiB/s, done.
# Resolving deltas: 100% (186/186), done.

# %%
import os

# Step 1: Create the "data" folder if it doesn't exist
data_folder_path = '/content/drive/Shareddrives/517 nlp project/data'
if not os.path.exists(data_folder_path):
    os.makedirs(data_folder_path)

# Step 2: Move the downloaded dataset folder to the "data" folder
source_path = '/content/drive/Shareddrives/517 nlp project/SVAMP'
destination_path = '/content/drive/Shareddrives/517 nlp project/data/SVAMP'

# Move the folder
# !mv "{source_path}" "{destination_path}"
